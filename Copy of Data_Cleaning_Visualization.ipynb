# %%
# Data Cleaning & Visualization Project
# Name: Harini G

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

sns.set_style("whitegrid")

# %%
import pandas as pd
url = "https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv"
df = pd.read_csv(url)

df.head(50)
# Out:
#     PassengerId  Survived  Pclass  \
# 0             1         0       3
# 1             2         1       1
# 2             3         1       3
# 3             4         1       1
# 4             5         0       3
# 5             6         0       3
# 6             7         0       1
# 7             8         0       3
# 8             9         1       3
# 9            10         1       2
# 10           11         1       3
# 11           12         1       1
# 12           13         0       3
# 13           14         0       3
# 14           15         0       3
# 15           16         1       2
# 16           17         0       3
# 17           18         1       2
# 18           19         0       3
# 19           20         1       3
# 20           21         0       2
# 21           22         1       2
# 22           23         1       3
# 23           24         1       1
# 24           25         0       3
# 25           26         1       3
# ...

# %%
df.tail(10)
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 881          882         0       3                        Markun, Mr. Johann
# 882          883         0       3              Dahlberg, Miss. Gerda Ulrika
# 883          884         0       2             Banfield, Mr. Frederick James
# 884          885         0       3                    Sutehall, Mr. Henry Jr
# 885          886         0       3      Rice, Mrs. William (Margaret Norton)
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked
# ...

# %%
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
df.shape
# Out:
# (891, 12)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
df["Age"] = df["Age"].fillna(df["Age"].median())

# %%
df["Fare"] = df["Fare"].fillna(df["Fare"].median())

# %%
df.drop("Cabin", axis=1, inplace=True)

# %%
df.isnull().sum()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Embarked       2
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.drop_duplicates(inplace=True)

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
plt.figure(figsize=(6,4))

sns.boxplot(x=df["Fare"])

plt.title("Fare Outliers")

plt.show()

# %%
Q1 = df["Fare"].quantile(0.25)

Q3 = df["Fare"].quantile(0.75)

IQR = Q3 - Q1

lower = Q1 - 1.5 * IQR

upper = Q3 + 1.5 * IQR

df = df[(df["Fare"] >= lower) & (df["Fare"] <= upper)]

# %%
df.shape
# Out:
# (775, 11)

# %%
df.to_csv("cleaned_titanic.csv", index=False)

# %%
plt.figure(figsize=(6,4))

plt.hist(df["Age"], bins=20)

plt.xlabel("Age")

plt.ylabel("Count")

plt.title("Age Distribution")

plt.show()

# %%
sns.countplot(x="Pclass", data=df)

plt.title("Passenger Class")

plt.show()

# %%
gender = df["Sex"].value_counts()

plt.pie(gender.values,
        labels=gender.index,
        autopct="%1.1f%%")

plt.title("Gender Distribution")

plt.show()

# %%
sns.scatterplot(
    x="Age",
    y="Fare",
    hue="Survived",
    data=df
)

plt.title("Age vs Fare")

plt.show()

# %%
numeric = df.select_dtypes(include=np.number)

plt.figure(figsize=(8,6))

sns.heatmap(
    numeric.corr(),
    annot=True,
    cmap="coolwarm"
)

plt.title("Correlation Matrix")

plt.show()

# %%
print("Total Records:", len(df))

print("Average Age:", round(df["Age"].mean(),2))

print("Average Fare:", round(df["Fare"].mean(),2))

print("Male Passengers:", (df["Sex"]=="male").sum())

print("Female Passengers:", (df["Sex"]=="female").sum())

print("Survival Rate:", round(df["Survived"].mean()*100,2), "%")
# Out:
# Total Records: 775
# Average Age: 28.75
# Average Fare: 17.82
# Male Passengers: 531
# Female Passengers: 244
# Survival Rate: 33.94 %

# %%
## Storytelling (Key Insights)
# #After cleaning and analyzing the Titanic dataset, several interesting insights were observed.

##1. The dataset initially contained missing values in the Age, Cabin, and Embarked columns. These were handled using appropriate preprocessing techniques.

##2. The Cabin column had a large number of missing values, so it was removed to improve data quality.

##3. Duplicate records were checked and removed to ensure accurate analysis.

##4. Outliers in the Fare column were detected using the IQR method and removed to reduce their effect on the analysis.

##5. Most passengers were between 20 and 40 years of age.

##6. Passenger Class 3 had the highest number of passengers.

##7. Female passengers had a higher survival rate compared to male passengers.

##8. The correlation heatmap showed relationships between numerical features such as Fare, Age, Passenger Class, and Survival.

##Overall, the cleaned dataset provided more reliable information, and the visualizations helped identify important trends and patterns.

# %%
from google.colab import files

files.download("cleaned_titanic.csv")
